# %%
import matplotlib.pyplot as plt
from numpy import array
from mpl_toolkits.basemap import Basemap
from matplotlib.patches import Polygon
from matplotlib.collections import PatchCollection
from matplotlib.patches import PathPatch
import pandas as pd

fig = plt.figure(1, figsize=(25,35))
#fig = plt.figure()

ax_asemrowo        = fig.add_subplot(111)
ax_benowo          = fig.add_subplot(111)
ax_bubutan         = fig.add_subplot(111)
ax_bulak           = fig.add_subplot(111)
ax_dukuhpakis      = fig.add_subplot(111)
ax_gayungan        = fig.add_subplot(111)
ax_genteng         = fig.add_subplot(111)
ax_gubeng          = fig.add_subplot(111)
ax_gununganyar     = fig.add_subplot(111)
ax_jambangan       = fig.add_subplot(111)
ax_karangpilang    = fig.add_subplot(111)
ax_kenjeran        = fig.add_subplot(111)
ax_krembangan      = fig.add_subplot(111)
ax_lakasantri      = fig.add_subplot(111)
ax_mulyorejo       = fig.add_subplot(111)
ax_pabeancantian   = fig.add_subplot(111)
ax_pakal           = fig.add_subplot(111)
ax_rungkut         = fig.add_subplot(111)
ax_sambikerep      = fig.add_subplot(111)
ax_sawahan         = fig.add_subplot(111)
ax_semampir        = fig.add_subplot(111)
ax_simokerto       = fig.add_subplot(111)
ax_sukolilo        = fig.add_subplot(111)
ax_sukomanunggal   = fig.add_subplot(111)
ax_tambaksari      = fig.add_subplot(111)
ax_tandes          = fig.add_subplot(111)
ax_tegalsari       = fig.add_subplot(111)
ax_tenggilismejoyo = fig.add_subplot(111)
ax_wiyung          = fig.add_subplot(111)
ax_wonocolo        = fig.add_subplot(111)
ax_wonokromo       = fig.add_subplot(111)

lon_min, lon_max = 112.51338, 112.872205
lat_min, lat_max = -7.357448, -7.178877

map = Basemap(llcrnrlat=lat_min,
              urcrnrlat=lat_max,
              llcrnrlon=lon_min,
              urcrnrlon=lon_max,
              resolution='h',
              projection='tmerc',
              epsg=2389)

map.drawmapboundary(fill_color='aqua')
map.fillcontinents(color='#ddaa66',lake_color='aqua')
map.drawcoastlines()

map.readshapefile('Kec_Surabaya_2017', 'Kec_Surabaya_2017')

asemrowo        = []
benowo          = []
bubutan         = []
bulak           = []
dukuhpakis      = []
gununganyar     = []
gayungan        = []
genteng         = []
gubeng          = []
gununganyar     = []
jambangan       = []
karangpilang    = []
kenjeran        = []
krembangan      = []
lakasantri      = []
mulyorejo       = []
pabeancantian   = []
pakal           = []
rungkut         = []
sambikerep      = []
sawahan         = []
semampir        = []
simokerto       = []
sukolilo        = []
sukomanunggal   = []
tambaksari      = []
tandes          = []
tegalsari       = []
tenggilismejoyo = []
wiyung          = []
wonocolo        = []
wonokromo       = []

#(use "r" before the path string to address special character, such as '\'). Don't forget to put the file name at the end of the path + '.xlsx'
df = pd.read_excel (r'C:\Users\pradh\sids\data_sma.xlsx', usecols=['Wilayah', 'Total'])

for info, shape in zip(map.Kec_Surabaya_2017_info, map.Kec_Surabaya_2017):
            
    if (info['name'] == 'Asemrowo'):
        if(df['Total'][0] == 0):
            asemrowo.append(Polygon(array(shape), True))
            ax_asemrowo.add_collection(PatchCollection(asemrowo, facecolor='red', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][0] > 0) and (df['Total'][0] <= 5)):
            asemrowo.append(Polygon(array(shape), True))
            ax_asemrowo.add_collection(PatchCollection(asemrowo, facecolor='Yellow', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][0] > 5) and (df['Total'][0] <= 10)):
            asemrowo.append(Polygon(array(shape), True))
            ax_asemrowo.add_collection(PatchCollection(asemrowo, facecolor='Green', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][0] > 10) and (df['Total'][0] <= 15)):
            asemrowo.append(Polygon(array(shape), True))
            ax_asemrowo.add_collection(PatchCollection(asemrowo, facecolor='Blue', edgecolor='k', linewidths=1, zorder=2))
            
    if (info['name'] == 'Benowo'):
        if(df['Total'][1] == 0):
            benowo.append(Polygon(array(shape), True))
            ax_benowo.add_collection(PatchCollection(benowo, facecolor='red', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][1] > 0) and (df['Total'][1] <= 5)):
            benowo.append(Polygon(array(shape), True))
            ax_benowo.add_collection(PatchCollection(benowo, facecolor='Yellow', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][1] > 5) and (df['Total'][1] <= 10)):
            benowo.append(Polygon(array(shape), True))
            ax_benowo.add_collection(PatchCollection(benowo, facecolor='Green', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][1] > 10) and (df['Total'][1] <= 15)):
            benowo.append(Polygon(array(shape), True))
            ax_benowo.add_collection(PatchCollection(benowo, facecolor='Blue', edgecolor='k', linewidths=1, zorder=2))
            
    if (info['name'] == 'Bubutan'):
        if(df['Total'][2] == 0):
            bubutan.append(Polygon(array(shape), True))
            ax_bubutan.add_collection(PatchCollection(bubutan, facecolor='red', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][2] > 0) and (df['Total'][2] <= 5)):
            bubutan.append(Polygon(array(shape), True))
            ax_bubutan.add_collection(PatchCollection(bubutan, facecolor='Yellow', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][2] > 5) and (df['Total'][2] <= 10)):
            bubutan.append(Polygon(array(shape), True))
            ax_bubutan.add_collection(PatchCollection(bubutan, facecolor='Green', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][2] > 10) and (df['Total'][2] <= 15)):
            bubutan.append(Polygon(array(shape), True))
            ax_bubutan.add_collection(PatchCollection(bubutan, facecolor='Blue', edgecolor='k', linewidths=1, zorder=2))
            
    if (info['name'] == 'Bulak'):
        if(df['Total'][3] == 0):
            bulak.append(Polygon(array(shape), True))
            ax_bulak.add_collection(PatchCollection(bulak, facecolor='red', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][3] > 0) and (df['Total'][3] <= 5)):
            bulak.append(Polygon(array(shape), True))
            ax_bulak.add_collection(PatchCollection(bulak, facecolor='Yellow', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][3] > 5) and (df['Total'][3] <= 10)):
            bulak.append(Polygon(array(shape), True))
            ax_bulak.add_collection(PatchCollection(bulak, facecolor='Green', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][3] > 10) and (df['Total'][3] <= 15)):
            bulak.append(Polygon(array(shape), True))
            ax_bulak.add_collection(PatchCollection(bulak, facecolor='Blue', edgecolor='k', linewidths=1, zorder=2))
            
    if (info['name'] == 'Dukuh Pakis'):
        if(df['Total'][4] == 0):
            dukuhpakis.append(Polygon(array(shape), True))
            ax_dukuhpakis.add_collection(PatchCollection(dukuhpakis, facecolor='red', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][4] > 0) and (df['Total'][4] <= 5)):
            dukuhpakis.append(Polygon(array(shape), True))
            ax_dukuhpakis.add_collection(PatchCollection(dukuhpakis, facecolor='Yellow', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][4] > 5) and (df['Total'][4] <= 10)):
            dukuhpakis.append(Polygon(array(shape), True))
            ax_dukuhpakis.add_collection(PatchCollection(dukuhpakis, facecolor='Green', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][4] > 10) and (df['Total'][4] <= 15)):
            dukuhpakis.append(Polygon(array(shape), True))
            ax_dukuhpakis.add_collection(PatchCollection(dukuhpakis, facecolor='Blue', edgecolor='k', linewidths=1, zorder=2))
            
    if (info['name'] == 'Gayungan'):
        if(df['Total'][5] == 0):
            gayungan.append(Polygon(array(shape), True))
            ax_gayungan.add_collection(PatchCollection(gayungan, facecolor='red', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][5] > 0) and (df['Total'][5] <= 5)):
            gayungan.append(Polygon(array(shape), True))
            ax_gayungan.add_collection(PatchCollection(gayungan, facecolor='Yellow', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][5] > 5) and (df['Total'][5] <= 10)):
            gayungan.append(Polygon(array(shape), True))
            ax_gayungan.add_collection(PatchCollection(gayungan, facecolor='Green', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][5] > 10) and (df['Total'][5] <= 15)):
            gayungan.append(Polygon(array(shape), True))
            ax_gayungan.add_collection(PatchCollection(gayungan, facecolor='Blue', edgecolor='k', linewidths=1, zorder=2))
            
    if (info['name'] == 'Genteng'):
        if(df['Total'][6] == 0):
            genteng.append(Polygon(array(shape), True))
            ax_genteng.add_collection(PatchCollection(genteng, facecolor='red', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][6] > 0) and (df['Total'][6] <= 5)):
            genteng.append(Polygon(array(shape), True))
            ax_genteng.add_collection(PatchCollection(genteng, facecolor='Yellow', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][6] > 5) and (df['Total'][6] <= 10)):
            genteng.append(Polygon(array(shape), True))
            ax_genteng.add_collection(PatchCollection(genteng, facecolor='Green', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][6] > 10) and (df['Total'][6] <= 15)):
            genteng.append(Polygon(array(shape), True))
            ax_genteng.add_collection(PatchCollection(genteng, facecolor='Blue', edgecolor='k', linewidths=1, zorder=2))
    
    if (info['name'] == 'Gubeng'):
        if(df['Total'][7] == 0):
            gubeng.append(Polygon(array(shape), True))
            ax_gubeng.add_collection(PatchCollection(gubeng, facecolor='red', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][7] > 0) and (df['Total'][7] <= 5)):
            gubeng.append(Polygon(array(shape), True))
            ax_gubeng.add_collection(PatchCollection(gubeng, facecolor='Yellow', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][7] > 5) and (df['Total'][7] <= 10)):
            gubeng.append(Polygon(array(shape), True))
            ax_gubeng.add_collection(PatchCollection(gubeng, facecolor='Green', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][7] > 10) and (df['Total'][7] <= 15)):
            gubeng.append(Polygon(array(shape), True))
            ax_gubeng.add_collection(PatchCollection(gubeng, facecolor='Blue', edgecolor='k', linewidths=1, zorder=2))
            
    if (info['name'] == 'Gunung Anyar'):
        if(df['Total'][8] == 0):
            gununganyar.append(Polygon(array(shape), True))
            ax_gununganyar.add_collection(PatchCollection(gununganyar, facecolor='red', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][8] > 0) and (df['Total'][8] <= 5)):
            gununganyar.append(Polygon(array(shape), True))
            ax_gununganyar.add_collection(PatchCollection(gununganyar, facecolor='Yellow', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][8] > 5) and (df['Total'][8] <= 10)):
            gununganyar.append(Polygon(array(shape), True))
            ax_gununganyar.add_collection(PatchCollection(gununganyar, facecolor='Green', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][8] > 10) and (df['Total'][8] <= 15)):
            gununganyar.append(Polygon(array(shape), True))
            ax_gununganyar.add_collection(PatchCollection(gununganyar, facecolor='Blue', edgecolor='k', linewidths=1, zorder=2))
            
    if (info['name'] == 'Jambangan'):
        if(df['Total'][9] == 0):
            jambangan.append(Polygon(array(shape), True))
            ax_jambangan.add_collection(PatchCollection(jambangan, facecolor='red', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][9] > 0) and (df['Total'][9] <= 5)):
            jambangan.append(Polygon(array(shape), True))
            ax_jambangan.add_collection(PatchCollection(jambangan, facecolor='Yellow', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][9] > 5) and (df['Total'][9] <= 10)):
            jambangan.append(Polygon(array(shape), True))
            ax_jambangan.add_collection(PatchCollection(jambangan, facecolor='Green', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][9] > 10) and (df['Total'][9] <= 15)):
            gubeng.append(Polygon(array(shape), True))
            ax_jambangan.add_collection(PatchCollection(gubeng, facecolor='Blue', edgecolor='k', linewidths=1, zorder=2))
            
    if (info['name'] == 'Karang Pilang'):
        if(df['Total'][10] == 0):
            karangpilang.append(Polygon(array(shape), True))
            ax_karangpilang.add_collection(PatchCollection(karangpilang, facecolor='red', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][10] > 0) and (df['Total'][10] <= 5)):
            karangpilang.append(Polygon(array(shape), True))
            ax_karangpilang.add_collection(PatchCollection(karangpilang, facecolor='Yellow', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][10] > 5) and (df['Total'][10] <= 10)):
            karangpilang.append(Polygon(array(shape), True))
            ax_karangpilang.add_collection(PatchCollection(karangpilang, facecolor='Green', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][10] > 10) and (df['Total'][10] <= 15)):
            karangpilang.append(Polygon(array(shape), True))
            ax_karangpilang.add_collection(PatchCollection(karangpilang, facecolor='Blue', edgecolor='k', linewidths=1, zorder=2))

    if (info['name'] == 'Kenjeran'):
        if(df['Total'][11] == 0):
            kenjeran.append(Polygon(array(shape), True))
            ax_kenjeran.add_collection(PatchCollection(kenjeran, facecolor='red', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][11] > 0) and (df['Total'][11] <= 5)):
            kenjeran.append(Polygon(array(shape), True))
            ax_kenjeran.add_collection(PatchCollection(kenjeran, facecolor='Yellow', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][11] > 5) and (df['Total'][11] <= 10)):
            kenjeran.append(Polygon(array(shape), True))
            ax_kenjeran.add_collection(PatchCollection(kenjeran, facecolor='Green', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][11] > 10) and (df['Total'][11] <= 15)):
            kenjeran.append(Polygon(array(shape), True))
            ax_kenjeran.add_collection(PatchCollection(kenjeran, facecolor='Blue', edgecolor='k', linewidths=1, zorder=2))
            
    if (info['name'] == 'Krembangan'):
        if(df['Total'][12] == 0):
            krembangan.append(Polygon(array(shape), True))
            ax_krembangan.add_collection(PatchCollection(krembangan, facecolor='red', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][12] > 0) and (df['Total'][12] <= 5)):
            krembangan.append(Polygon(array(shape), True))
            ax_krembangan.add_collection(PatchCollection(krembangan, facecolor='Yellow', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][12] > 5) and (df['Total'][12] <= 10)):
            krembangan.append(Polygon(array(shape), True))
            ax_krembangan.add_collection(PatchCollection(krembangan, facecolor='Green', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][12] > 10) and (df['Total'][12] <= 15)):
            krembangan.append(Polygon(array(shape), True))
            ax_krembangan.add_collection(PatchCollection(krembangan, facecolor='Blue', edgecolor='k', linewidths=1, zorder=2))       
            
    if (info['name'] == 'Lakarsantri'):
        if(df['Total'][13] == 0):
            lakasantri.append(Polygon(array(shape), True))
            ax_lakasantri.add_collection(PatchCollection(lakasantri, facecolor='red', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][13] > 0) and (df['Total'][13] <= 5)):
            lakasantri.append(Polygon(array(shape), True))
            ax_lakasantri.add_collection(PatchCollection(lakasantri, facecolor='Yellow', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][13] > 5) and (df['Total'][13] <= 10)):
            lakasantri.append(Polygon(array(shape), True))
            ax_lakasantri.add_collection(PatchCollection(lakasantri, facecolor='Green', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][13] > 10) and (df['Total'][13] <= 15)):
            lakasantri.append(Polygon(array(shape), True))
            ax_lakasantri.add_collection(PatchCollection(lakasantri, facecolor='Blue', edgecolor='k', linewidths=1, zorder=2))
            
    if (info['name'] == 'Mulyorejo'):
        if(df['Total'][14] == 0):
            mulyorejo.append(Polygon(array(shape), True))
            ax_krembangan.add_collection(PatchCollection(krembangan, facecolor='red', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][14] > 0) and (df['Total'][14] <= 5)):
            krembangan.append(Polygon(array(shape), True))
            ax_krembangan.add_collection(PatchCollection(krembangan, facecolor='Yellow', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][14] > 5) and (df['Total'][14] <= 10)):
            krembangan.append(Polygon(array(shape), True))
            ax_krembangan.add_collection(PatchCollection(krembangan, facecolor='Green', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][14] > 10) and (df['Total'][14] <= 15)):
            krembangan.append(Polygon(array(shape), True))
            ax_krembangan.add_collection(PatchCollection(krembangan, facecolor='Blue', edgecolor='k', linewidths=1, zorder=2)) 
    
    if (info['name'] == 'Pabean Cantian'):
        if(df['Total'][15] == 0):
            pabeancantian.append(Polygon(array(shape), True))
            ax_pabeancantian.add_collection(PatchCollection(pabeancantian, facecolor='red', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][15] > 0) and (df['Total'][15] <= 5)):
            pabeancantian.append(Polygon(array(shape), True))
            ax_pabeancantian.add_collection(PatchCollection(pabeancantian, facecolor='Yellow', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][15] > 5) and (df['Total'][15] <= 10)):
            pabeancantian.append(Polygon(array(shape), True))
            ax_pabeancantian.add_collection(PatchCollection(pabeancantian, facecolor='Green', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][15] > 10) and (df['Total'][15] <= 15)):
            pabeancantian.append(Polygon(array(shape), True))
            ax_pabeancantian.add_collection(PatchCollection(pabeancantian, facecolor='Blue', edgecolor='k', linewidths=1, zorder=2))
            
    if (info['name'] == 'Pakal'):
        if(df['Total'][16] == 0):
            pakal.append(Polygon(array(shape), True))
            ax_pakal.add_collection(PatchCollection(pakal, facecolor='red', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][16] > 0) and (df['Total'][16] <= 5)):
            pakal.append(Polygon(array(shape), True))
            ax_pakal.add_collection(PatchCollection(pakal, facecolor='Yellow', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][16] > 5) and (df['Total'][16] <= 10)):
            pakal.append(Polygon(array(shape), True))
            ax_pakal.add_collection(PatchCollection(pakal, facecolor='Green', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][16] > 10) and (df['Total'][16] <= 15)):
            pakal.append(Polygon(array(shape), True))
            ax_pakal.add_collection(PatchCollection(pakal, facecolor='Blue', edgecolor='k', linewidths=1, zorder=2))        
    
    if (info['name'] == 'Rungkut'):
        if(df['Total'][17] == 0):
            rungkut.append(Polygon(array(shape), True))
            ax_rungkut.add_collection(PatchCollection(rungkut, facecolor='red', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][17] > 0) and (df['Total'][17] <= 5)):
            rungkut.append(Polygon(array(shape), True))
            ax_rungkut.add_collection(PatchCollection(rungkut, facecolor='Yellow', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][17] > 5) and (df['Total'][17] <= 10)):
            rungkut.append(Polygon(array(shape), True))
            ax_rungkut.add_collection(PatchCollection(rungkut, facecolor='Green', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][17] > 10) and (df['Total'][17] <= 15)):
            rungkut.append(Polygon(array(shape), True))
            ax_rungkut.add_collection(PatchCollection(rungkut, facecolor='Blue', edgecolor='k', linewidths=1, zorder=2))
            
    if (info['name'] == 'Sambikerep'):
        if(df['Total'][18] == 0):
            sambikerep.append(Polygon(array(shape), True))
            ax_sambikerep.add_collection(PatchCollection(sambikerep, facecolor='red', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][18] > 0) and (df['Total'][18] <= 5)):
            sambikerep.append(Polygon(array(shape), True))
            ax_sambikerep.add_collection(PatchCollection(sambikerep, facecolor='Yellow', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][18] > 5) and (df['Total'][18] <= 10)):
            sambikerep.append(Polygon(array(shape), True))
            ax_sambikerep.add_collection(PatchCollection(sambikerep, facecolor='Green', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][18] > 10) and (df['Total'][18] <= 15)):
            sambikerep.append(Polygon(array(shape), True))
            ax_sambikerep.add_collection(PatchCollection(sambikerep, facecolor='Blue', edgecolor='k', linewidths=1, zorder=2))
    
    if (info['name'] == 'Sawahan'):
        if(df['Total'][19] == 0):
            sawahan.append(Polygon(array(shape), True))
            ax_sawahan.add_collection(PatchCollection(sawahan, facecolor='red', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][19] > 0) and (df['Total'][19] <= 5)):
            sawahan.append(Polygon(array(shape), True))
            ax_sawahan.add_collection(PatchCollection(sawahan, facecolor='Yellow', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][19] > 5) and (df['Total'][19] <= 10)):
            sawahan.append(Polygon(array(shape), True))
            ax_sawahan.add_collection(PatchCollection(sawahan, facecolor='Green', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][19] > 10) and (df['Total'][19] <= 15)):
            sawahan.append(Polygon(array(shape), True))
            ax_sawahan.add_collection(PatchCollection(sawahan, facecolor='Blue', edgecolor='k', linewidths=1, zorder=2))
            
    if (info['name'] == 'Semampir'):
        if(df['Total'][20] == 0):
            semampir.append(Polygon(array(shape), True))
            ax_semampir.add_collection(PatchCollection(semampir, facecolor='red', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][20] > 0) and (df['Total'][20] <= 5)):
            semampir.append(Polygon(array(shape), True))
            ax_semampir.add_collection(PatchCollection(semampir, facecolor='Yellow', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][20] > 5) and (df['Total'][20] <= 10)):
            semampir.append(Polygon(array(shape), True))
            ax_semampir.add_collection(PatchCollection(semampir, facecolor='Green', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][20] > 10) and (df['Total'][20] <= 15)):
            semampir.append(Polygon(array(shape), True))
            ax_semampir.add_collection(PatchCollection(semampir, facecolor='Blue', edgecolor='k', linewidths=1, zorder=2))
    
    if (info['name'] == 'Simokerto'):
        if(df['Total'][21] == 0):
            simokerto.append(Polygon(array(shape), True))
            ax_simokerto.add_collection(PatchCollection(simokerto, facecolor='red', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][21] > 0) and (df['Total'][21] <= 5)):
            simokerto.append(Polygon(array(shape), True))
            ax_simokerto.add_collection(PatchCollection(simokerto, facecolor='Yellow', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][21] > 5) and (df['Total'][21] <= 10)):
            simokerto.append(Polygon(array(shape), True))
            ax_simokerto.add_collection(PatchCollection(simokerto, facecolor='Green', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][21] > 10) and (df['Total'][21] <= 15)):
            simokerto.append(Polygon(array(shape), True))
            ax_simokerto.add_collection(PatchCollection(simokerto, facecolor='Blue', edgecolor='k', linewidths=1, zorder=2))
                      
    if (info['name'] == 'Sukolilo'):
        if(df['Total'][22] == 0):
            sukolilo.append(Polygon(array(shape), True))
            ax_sukolilo.add_collection(PatchCollection(sukolilo, facecolor='red', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][22] > 0) and (df['Total'][22] <= 5)):
            sukolilo.append(Polygon(array(shape), True))
            ax_sukolilo.add_collection(PatchCollection(sukolilo, facecolor='Yellow', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][22] > 5) and (df['Total'][22] <= 10)):
            sukolilo.append(Polygon(array(shape), True))
            ax_sukolilo.add_collection(PatchCollection(sukolilo, facecolor='Green', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][22] > 10) and (df['Total'][22] <= 15)):
            sukolilo.append(Polygon(array(shape), True))
            ax_sukolilo.add_collection(PatchCollection(sukolilo, facecolor='Blue', edgecolor='k', linewidths=1, zorder=2))
            
    if (info['name'] == 'Sukomanunggal'):
        if(df['Total'][23] == 0):
            sukomanunggal.append(Polygon(array(shape), True))
            ax_sukomanunggal.add_collection(PatchCollection(sukomanunggal, facecolor='red', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][23] > 0) and (df['Total'][23] <= 5)):
            sukomanunggal.append(Polygon(array(shape), True))
            ax_sukomanunggal.add_collection(PatchCollection(sukomanunggal, facecolor='Yellow', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][23] > 5) and (df['Total'][23] <= 10)):
            sukomanunggal.append(Polygon(array(shape), True))
            ax_sukomanunggal.add_collection(PatchCollection(sukomanunggal, facecolor='Green', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][23] > 10) and (df['Total'][23] <= 15)):
            sukomanunggal.append(Polygon(array(shape), True))
            ax_sukomanunggal.add_collection(PatchCollection(sukomanunggal, facecolor='Blue', edgecolor='k', linewidths=1, zorder=2))
    
    if (info['name'] == 'Tambaksari'):
        if(df['Total'][24] == 0):
            tambaksari.append(Polygon(array(shape), True))
            ax_tambaksari.add_collection(PatchCollection(tambaksari, facecolor='red', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][24] > 0) and (df['Total'][24] <= 5)):
            tambaksari.append(Polygon(array(shape), True))
            ax_tambaksari.add_collection(PatchCollection(tambaksari, facecolor='Yellow', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][24] > 5) and (df['Total'][24] <= 10)):
            tambaksari.append(Polygon(array(shape), True))
            ax_tambaksari.add_collection(PatchCollection(tambaksari, facecolor='Green', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][24] > 10) and (df['Total'][24] <= 15)):
            tambaksari.append(Polygon(array(shape), True))
            ax_tambaksari.add_collection(PatchCollection(tambaksari, facecolor='Blue', edgecolor='k', linewidths=1, zorder=2))
            
    if (info['name'] == 'Tandes'):
        if(df['Total'][25] == 0):
            tandes.append(Polygon(array(shape), True))
            ax_tandes.add_collection(PatchCollection(tandes, facecolor='red', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][25] > 0) and (df['Total'][25] <= 5)):
            tandes.append(Polygon(array(shape), True))
            ax_tandes.add_collection(PatchCollection(tandes, facecolor='Yellow', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][25] > 5) and (df['Total'][25] <= 10)):
            tandes.append(Polygon(array(shape), True))
            ax_tandes.add_collection(PatchCollection(tandes, facecolor='Green', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][25] > 10) and (df['Total'][25] <= 15)):
            tandes.append(Polygon(array(shape), True))
            ax_tandes.add_collection(PatchCollection(tandes, facecolor='Blue', edgecolor='k', linewidths=1, zorder=2))
    
    if (info['name'] == 'Tegalsari'):
        if(df['Total'][26] == 0):
            tegalsari.append(Polygon(array(shape), True))
            ax_tegalsari.add_collection(PatchCollection(tegalsari, facecolor='red', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][26] > 0) and (df['Total'][26] <= 5)):
            tegalsari.append(Polygon(array(shape), True))
            ax_tegalsari.add_collection(PatchCollection(tegalsari, facecolor='Yellow', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][26] > 5) and (df['Total'][26] <= 10)):
            tegalsari.append(Polygon(array(shape), True))
            ax_tegalsari.add_collection(PatchCollection(tegalsari, facecolor='Green', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][26] > 10) and (df['Total'][26] <= 15)):
            tegalsari.append(Polygon(array(shape), True))
            ax_tegalsari.add_collection(PatchCollection(tegalsari, facecolor='Blue', edgecolor='k', linewidths=1, zorder=2))
            
    if (info['name'] == 'Tenggilis Mejoyo'):
        if(df['Total'][27] == 0):
            tenggilismejoyo.append(Polygon(array(shape), True))
            ax_tenggilismejoyo.add_collection(PatchCollection(tenggilismejoyo, facecolor='red', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][27] > 0) and (df['Total'][27] <= 5)):
            tenggilismejoyo.append(Polygon(array(shape), True))
            ax_tenggilismejoyo.add_collection(PatchCollection(tenggilismejoyo, facecolor='Yellow', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][27] > 5) and (df['Total'][27] <= 10)):
            tenggilismejoyo.append(Polygon(array(shape), True))
            ax_tenggilismejoyo.add_collection(PatchCollection(tenggilismejoyo, facecolor='Green', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][27] > 10) and (df['Total'][27] <= 15)):
            tenggilismejoyo.append(Polygon(array(shape), True))
            ax_tenggilismejoyo.add_collection(PatchCollection(tenggilismejoyo, facecolor='Blue', edgecolor='k', linewidths=1, zorder=2))
    
    if (info['name'] == 'Wiyung'):
        if(df['Total'][28] == 0):
            wiyung.append(Polygon(array(shape), True))
            ax_wiyung.add_collection(PatchCollection(wiyung, facecolor='red', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][28] > 0) and (df['Total'][28] <= 5)):
            wiyung.append(Polygon(array(shape), True))
            ax_wiyung.add_collection(PatchCollection(wiyung, facecolor='Yellow', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][28] > 5) and (df['Total'][28] <= 10)):
            wiyung.append(Polygon(array(shape), True))
            ax_wiyung.add_collection(PatchCollection(wiyung, facecolor='Green', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][28] > 10) and (df['Total'][28] <= 15)):
            wiyung.append(Polygon(array(shape), True))
            ax_wiyung.add_collection(PatchCollection(wiyung, facecolor='Blue', edgecolor='k', linewidths=1, zorder=2))
    
    if (info['name'] == 'Wonocolo'):
        if(df['Total'][29] == 0):
            wonocolo.append(Polygon(array(shape), True))
            ax_wonocolo.add_collection(PatchCollection(wonocolo, facecolor='red', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][29] > 0) and (df['Total'][29] <= 5)):
            wonocolo.append(Polygon(array(shape), True))
            ax_wonocolo.add_collection(PatchCollection(wonocolo, facecolor='Yellow', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][29] > 5) and (df['Total'][29] <= 10)):
            wonocolo.append(Polygon(array(shape), True))
            ax_wonocolo.add_collection(PatchCollection(wonocolo, facecolor='Green', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][29] > 10) and (df['Total'][29] <= 15)):
            wonocolo.append(Polygon(array(shape), True))
            ax_wonocolo.add_collection(PatchCollection(wonocolo, facecolor='Blue', edgecolor='k', linewidths=1, zorder=2))
    
    if (info['name'] == 'Wonokromo'):
        if(df['Total'][30] == 0):
            wonokromo.append(Polygon(array(shape), True))
            ax_wonokromo.add_collection(PatchCollection(wonokromo, facecolor='red', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][30] > 0) and (df['Total'][30] <= 5)):
            wonokromo.append(Polygon(array(shape), True))
            ax_wonokromo.add_collection(PatchCollection(wonokromo, facecolor='Yellow', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][30] > 5) and (df['Total'][30] <= 10)):
            wonokromo.append(Polygon(array(shape), True))
            ax_wonokromo.add_collection(PatchCollection(wonokromo, facecolor='Green', edgecolor='k', linewidths=1, zorder=2))
        elif((df['Total'][30] > 10) and (df['Total'][30] <= 15)):
            wonokromo.append(Polygon(array(shape), True))
            ax_wonokromo.add_collection(PatchCollection(wonokromo, facecolor='Blue', edgecolor='k', linewidths=1, zorder=2))

plt.show()
